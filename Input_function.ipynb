# %% [markdown]
# # INPUT()

# %%
x=input()
y=input()
z=x+y
print(z)
# Out:
#  5
#  3
# 53

# %%
print(type(x))
# Out:
# <class 'str'>

# %%
print(x)
# Out:
# 5

# %%
x1=int(input('enter the 1st number: '))
y1=int(input('enter the 2nd number: '))
z1=x1+y1
print(z1)
# Out:
# enter the 1st number:  12
# enter the 2nd number:  33
# 45

# %%
st =input('enter a string')
print(st)
# Out:
# enter a string hello
# hello

# %%
print(st[3])
# Out:
# l

# %%
print(st[0:2])
# Out:
# he

# %%
print(st[-3])
# Out:
# l

# %%
st1 =input('enter a string')[0:4]
print(st1)
# Out:
# enter a string hello
# hell

# %%
str1=input('enter a string')[12:]
print(str1)
# Out:
# enter a string 2234 9654 364689456
# 4689456

# %%
adhar=input('enter athe  aadhar card number: ')[9:]
print(adhar)
# Out:
# enter athe  aadhar card number:  2234 2236 2235
#  2235

# %%
result=input('enter an expr')
print(result)
# Out:
# enter an expr 2+3+5*8
# 2+3+5*8

# %%
result=eval(input('enter an expr'))
print(result)
# Out:
# enter an expr 2+5*8-9
# 33
