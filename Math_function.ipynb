# %%
25
# Out:
# 25

# %%
sqrt(25)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 sqrt(25)
#
# NameError: name 'sqrt' is not defined

# %%
import math
math.sqrt(25)
# Out:
# 5.0

# %%
math.floor(3.5)
# Out:
# 3

# %%
math.ceil(3.5)
# Out:
# 4

# %%
math.floor(4.9)
# Out:
# 4

# %%
math.ceil(4.4)
# Out:
# 5

# %%
math.pow(2,3)
# Out:
# 8.0

# %%
math.pow(2,4)
# Out:
# 16.0

# %%
m.floor(3.4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 m.floor(3.4)
#
# NameError: name 'm' is not defined

# %%
import math as m
print(m.floor(37.9))
print(m.ceil(46.8))
print(m.pow(2,5))
print(m.sqrt(36))
# Out:
# 37
# 47
# 32.0
# 6.0

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
from math import pow,floor,ceil,sqrt
print(floor(37.9))
print(ceil(46.8))
print(pow(2,5))
print(sqrt(36))
# Out:
# 37
# 47
# 32.0
# 6.0

# %%
from math import *  #print all math module  inbulid function what ever user want
print(floor(37.9))
print(ceil(46.8))
print(pow(2,5))
print(sqrt(36))
# Out:
# 37
# 47
# 32.0
# 6.0
