# %%
bin(25)  #number system to binary
# Out:
# '0b11001'

# %%
bin(30)
# Out:
# '0b11110'

# %%
int(0b11110)
# Out:
# 30

# %%
oct(25) #number to octal number system
# Out:
# '0o31'

# %%
int(0o31)
# Out:
# 25

# %%
hex(1)
# Out:
# '0x1'

# %%
hex(10)
# Out:
# '0xa'

# %%
hex(15)
# Out:
# '0xf'

# %% [markdown]
# # Complement

# %%
~12
# Out:
# -13

# %%
~35
# Out:
# -36

# %%
12 & 13 #bitwise & (and) operator
# Out:
# 12

# %%
12 | 13 #bitwise | (or) operator
# Out:
# 13

# %%
12 ^ 13 #bitwise ^ (Xor) operator
# Out:
# 1

# %%
12 << 2  #bitwise << (LEFT SHIFT) operator
# Out:
# 48

# %%
12>>1 #bitwise >> (RIGHT SHIFT) operator
# Out:
# 6

# %%
12 >>2
# Out:
# 3
