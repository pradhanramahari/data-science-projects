# %% [markdown]
# # ARITHMETIC OPERATORS

# %%
x,y=10,5
x+y
# Out:
# 15

# %%
x-y
# Out:
# 5

# %%
x*y
# Out:
# 50

# %%
x/y
# Out:
# 2.0

# %%
x//y
# Out:
# 2

# %%
x%y
# Out:
# 0

# %%
x**y
# Out:
# 100000

# %% [markdown]
# # ASSIGNMENT

# %%
x=2
x=x+2
x
# Out:
# 4

# %%
x+=2
x
# Out:
# 8

# %%
x-=2
x
# Out:
# 6

# %%
x*=2
x
# Out:
# 24

# %%
x/=2
x
# Out:
# 12.0

# %%
x//=2
x
# Out:
# 6.0

# %% [markdown]
# # Relational operator

# %%
a = 10
b = 20
a>b
# Out:
# False

# %%
a<b
# Out:
# True

# %%
a=20
b=20
a>=b
# Out:
# True

# %%
a<=b
# Out:
# True

# %%
a=20
b=10
a!=b
# Out:
# True

# %%
a==b
# Out:
# False

# %% [markdown]
#  # Logical operator

# %%
a=5
b=4

# %%
print(a>2 and b>1)
# Out:
# True

# %%
print(a<8 and b<2) #and operator
# Out:
# False

# %%
a<10 or b>2 # or operator
# Out:
# True

# %%
x=False
x           # not operator
# Out:
# False

# %%
not x
# Out:
# True

# %%
y=True
y
# Out:
# True

# %%
not y
# Out:
# False
