# %% [markdown]
# # python all data type

# %%
#integer number
i=5
i
# Out:
# 5

# %%
type(i)
# Out:
# int

# %%
id(i)
# Out:
# 140735644869672

# %%
age=22
age
# Out:
# 22

# %%
print(type(age))
print(id(age))
# Out:
# <class 'int'>
# 140735644870216

# %% [markdown]
# # float

# %%
price=440.8
price
# Out:
# 440.8

# %%
print(type(price))
print(id(price))
# Out:
# <class 'float'>
# 1407117332560

# %% [markdown]
# # Boolen

# %%
import keywoard
keywoard.kwlist
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 import keywoard
#       2 keywoard.kwlist
#
# ModuleNotFoundError: No module named 'keywoard'

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
Active=True
True
# Out:
# True

# %%
print(type(Active))
print(id(Active))
# Out:
# <class 'bool'>
# 140735643957728

# %%
p=30
q=30
print(p,q)
# Out:
# 30 30

# %%
p,q=30,30
p,q
print(id(p))
print(id(q))
# Out:
# 140735577106248
# 140735577106248

# %% [markdown]
# # complex

# %%
c=10+20j
c
# Out:
# (10+20j)

# %%
type(c)
# Out:
# complex

# %%
c
# Out:
# (10+20j)

# %%
c.real
# Out:
# 10.0

# %%
c.imag
# Out:
# 20.0

# %%
c.s

# %% [markdown]
# # String

# %%
name="hari" #DOUBLE 
name
# Out:
# 'karapada'

# %%
s1='none'
s1
# Out:
# 'none'

# %%
s2=" welcome to karapada
    my name hari"
s2
# Out:
#   Cell In[4], line 1
#     s2=' welcome to karapada
#        ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
s3='''welcome to karapada
    my name har'''
s3
# Out:
# 'welcome to karapada\n    my name har'

# %%
# String index
str1="HELLO PYTHON"
str1
# Out:
# 'HELLO PYTHON'

# %%
str1[0]
# Out:
# 'H'

# %%
si="welcome"
si
# Out:
# 'welcome'

# %%
si[6]
# Out:
# 'e'

# %%
si
# Out:
# 'welcome'

# %%
si[-1]
# Out:
# 'e'

# %%
si[-2]
# Out:
# 'm'

# %%
si[-7]
# Out:
# 'w'

# %%
si[-100]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 si[-100]
#
# IndexError: string index out of range

# %% [markdown]
# # SLICING

# %%
si
# Out:
# 'welcome'

# %%
si[:] #all print
# Out:
# 'welcome'

# %%
si[1:4]#elc
# Out:
# 'elc'

# %%
si[0:6]
# Out:
# 'welcom'

# %%
si[3:10]
# Out:
# 'come'

# %%
si[3:5]
# Out:
# 'co'

# %%
si[2:]
# Out:
# 'lcome'

# %%
si[ :4]
# Out:
# 'welc'

# %%
si
# Out:
# 'welcome'

# %%
si[ :6]
# Out:
# 'welcom'

# %%
s = "Programming"
print(s[3:-2])
# Out:
# grammi

# %% [markdown]
# ## SLICING STEP

# %%
sl="karapada"
sl
# Out:
# 'karapada'

# %%
sl[:4]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 sl[:4]
#
# NameError: name 'sl' is not defined

# %%
sl[:4:2]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 sl[:4:2]
#
# NameError: name 'sl' is not defined

# %%
sl[:-4]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 sl[:-4]
#
# NameError: name 'sl' is not defined

# %%
si="welcome"
si
# Out:
# 'welcome'

# %%
si[0:7:2]
# Out:
# 'wloe'

# %%
si[-5:-1]
# Out:
# 'lcom'

# %%
si
# Out:
# 'welcome'

# %%
si[::2] #advance slicing
# Out:
# 'wloe'

# %%
si[::3]
# Out:
# 'wce'

# %%
si[::-1]
# Out:
# 'emoclew'

# %%
si[::-2]
# Out:
# 'eolw'
