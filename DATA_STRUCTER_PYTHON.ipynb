# %% [markdown]
# ## LIST DATASTRUCTER

# %%
l=[] #empty list
l
# Out:
# []

# %%
type(l)
# Out:
# list

# %%
len(l)
# Out:
# 0

# %%
l.append(10)
l
# Out:
# [10]

# %%
len(l)
l
# Out:
# [10]

# %%
len(l)
# Out:
# 1

# %%
l.append(20)
l
# Out:
# [10, 20]

# %%
l.append(40,90,80) # append only one argument pass
l
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 l.append(40,90,80)
#       2 l
#
# TypeError: list.append() takes exactly one argument (3 given)

# %%
l
# Out:
# [10, 20]

# %%
l.append(30)
l.append(40)
l.append(50)
l
# Out:
# [10, 20, 30, 40, 50]

# %%
len(l)
# Out:
# 5

# %%
l.append(10)
l
# Out:
# [10, 20, 30, 40, 50, 10, 10, 10]

# %%
l
# Out:
# [10, 20, 30, 40, 50, 10, 10, 10]

# %%
l1= [10,20.5,True,1+2j,'welcome'] # multipul data type
l1
# Out:
# [10, 20.5, True, (1+2j), 'welcome']

# %%
l1.append([1,2,3]) # nested list
l1
# Out:
# [10, 20.5, True, (1+2j), 'welcome', [1, 2, 3]]

# %%
print(l)
print(l1)
# Out:
# [10, 20, 30, 40, 50, 10, 10, 10]
# [10, 20.5, True, (1+2j), 'welcome', [1, 2, 3]]

# %%
l2=l.copy()
l2
# Out:
# [10, 20, 30, 40, 50, 10, 10, 10]

# %%
print(l)
print(l1)
print(l2)
# Out:
# [10, 20, 30, 40, 50, 10, 10, 10]
# [10, 20.5, True, (1+2j), 'welcome', [1, 2, 3]]
# [10, 20, 30, 40, 50, 10, 10, 10]

# %%
l == l2
# Out:
# True

# %%
len(l) == len(l2)
# Out:
# True

# %%
type(l) == type(l2)
# Out:
# True

# %%
id(l) == id(l2)
# Out:
# False

# %%
id(l) != id(l2)
# Out:
# True

# %%
print(id(l))
print(id(l2))  # id() function represent to memory address
# Out:
# 2595431866176
# 2595440100224

# %%
print(l)
print(l1)
print(l2)
# Out:
# [10, 20, 30, 40, 50, 10, 10, 10]
# [10, 20.5, True, (1+2j), 'welcome', [1, 2, 3]]
# [10, 20, 30, 40, 50, 10, 10, 10]

# %%
l2.clear() #clear function
print(l2)
# Out:
# []

# %%
print(l)
print(l1)
print(l2)
# Out:
# [10, 20, 30, 40, 50, 10, 10, 10]
# [10, 20.5, True, (1+2j), 'welcome', [1, 2, 3]]
# []

# %%
del l2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 del l2
#
# NameError: name 'l2' is not defined

# %% [markdown]
# # list count() function

# %%
num=[30,10,20,30,40,20,30,30,]
print(num)
# Out:
# [30, 10, 20, 30, 40, 20, 30, 30]

# %%
num.count(20)
# Out:
# 2

# %%
num.count(30)
# Out:
# 4

# %% [markdown]
# ## list extend() function

# %%
num1=[10,20,30,40]
num2=[90,80.5,True,10+2j,'hari']
print(num1)
print(num2)
# Out:
# [10, 20, 30, 40]
# [90, 80.5, True, (10+2j), 'hari']

# %%
num1.extend(num2) #concate all 
num1
# Out:
# [10,
#  20,
#  30,
#  40,
#  90,
#  80.5,
#  True,
#  (10+2j),
#  'hari',
#  90,
#  80.5,
#  True,
#  (10+2j),
#  'hari']

# %%
a =[1,2,3,4]
b =[9,8,7]

# %%
a.extend(b)
a
# Out:
# [1, 2, 3, 4, 9, 8, 7]

# %%
print(len(a))
print(len(b))
# Out:
# 7
# 3

# %%
print(a)
print(b)
# Out:
# [1, 2, 3, 4, 9, 8, 7]
# [9, 8, 7]

# %% [markdown]
# ## list index()

# %%
num2
# Out:
# [90, 80.5, True, (10+2j), 'hari']

# %%
num2.index('hari')
# Out:
# 4

# %%
num2.index(10+2j)
# Out:
# 3

# %%
num2
# Out:
# [90, 80.5, True, (10+2j), 'hari']

# %%
num2[0]=100 #list are mutable & changeble
num2
# Out:
# [100, 80.5, True, (10+2j), 'hari']

# %%
l2

# %%
l2=[10,20,30]
l2[0]
# Out:
# 10

# %%
l2[0]=100 #list are mutable 
l2
# Out:
# [100, 20, 30]

# %% [markdown]
# ## LIST INSORT()

# %%
l2
# Out:
# [100, 20, 30]

# %%
l2.insert(1,40)
l2
# Out:
# [100, 40, 20, 30]

# %%
l2.insert(2,[1,2,3])
l2
# Out:
# [100, 40, [1, 2, 3], 20, 30]

# %% [markdown]
# ## LIST pop()

# %%
l2
# Out:
# [100, 40, [1, 2, 3], 20, 30]

# %%
l2.pop()
l2
# Out:
# [100, 40, [1, 2, 3], 20]

# %%
l2.pop()
l2
# Out:
# [100, 40, [1, 2, 3]]

# %%
l2.pop(0)
l2
# Out:
# [40, [1, 2, 3]]

# %% [markdown]
# ## LIST REMOVE()

# %%
l3=[12,22.4,'nit',20+2j,True]
l3
# Out:
# [12, 22.4, 'nit', (20+2j), True]

# %%
l3.remove(True)
l3
# Out:
# [12, 22.4, 'nit', (20+2j)]

# %% [markdown]
# ## LIST REVERSE()

# %%
l3
# Out:
# [12, 22.4, 'nit', (20+2j)]

# %%
l3.reverse()
l3
# Out:
# [(20+2j), 'nit', 22.4, 12]

# %%
l3[::-1]
l3
# Out:
# [(20+2j), 'nit', 22.4, 12]

# %%
l4=['a','b','c','d']
l4
# Out:
# ['a', 'b', 'c', 'd']

# %%
l4.reverse()
l4
# Out:
# ['d', 'c', 'b', 'a']

# %% [markdown]
# ## LIST SORTING

# %%
l5=[3,200,33,1000,20,10]
l5
# Out:
# [3, 200, 33, 1000, 20, 10]

# %%
l5.sort() # sort function bydafult it given ascending sorting .
l5
# Out:
# [3, 10, 20, 33, 200, 1000]

# %%
l5.sort( reverse=True) ## descending order sorting.
l5
# Out:
# [1000, 200, 33, 20, 10, 3]
