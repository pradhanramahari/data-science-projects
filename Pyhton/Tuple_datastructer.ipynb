# %% [markdown]
# ## Tuple

# %%
t=() #empty tuple
t
# Out:
# ()

# %%
type(t)
# Out:
# tuple

# %%
t1=(10,True,11.5,'welcome',1+2j) # tuple multiple are allowed 
t1
# Out:
# (10, True, 11.5, 'welcome', (1+2j))

# %%
t1[0]
# Out:
# 10

# %%
t1[1:4]
# Out:
# (True, 11.5, 'welcome')

# %%
t1.count(10)
# Out:
# 1

# %%
t1.index("welcome")
# Out:
# 3

# %%
t1
# Out:
# (10, True, 11.5, 'welcome', (1+2j))

# %%
t=(10,20,30)
t
# Out:
# (10, 20, 30)

# %%
t*3 # 3 time repeat
# Out:
# (10, 20, 30, 10, 20, 30, 10, 20, 30)

# %%
sbi=(1234,'sidp2234',2000,'hyd') #inmutable 
sbi
# Out:
# (1234, 'sidp2234', 2000, 'hyd')
