# %% [markdown]
# # type() function
# a="5"
# name="hari"
# type(name)

# %%
price=990.89
type(price)
# Out:
# float

# %%
I_ACTIVE=True
type(I_ACTIVE)
# Out:
# bool

# %%
num=30
type(num)
# Out:
# int
