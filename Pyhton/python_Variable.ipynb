# %% [markdown]
# # variable

# %%
v=5
v
# Out:
# 5

# %%
nit =23
nit
# Out:
# 23

# %%
1nit =23
nit
# Out:
#   Cell In[5], line 1
#     1nit =23
#     ^
# SyntaxError: invalid decimal literal

# %%
v1=33
v1
# Out:
# 33

# %%
print(nit)
print(v1)
# Out:
# 23
# 33

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
len(keyword.kwlist)
# Out:
# 35
