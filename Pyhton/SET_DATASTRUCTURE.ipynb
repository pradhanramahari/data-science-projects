# %% [markdown]
#  ## SET

# %%
s={}
s
# Out:
# {}

# %%
type(s) # empty dect
# Out:
# dict

# %%
s1={1,2,3,3} #set 
s1
# Out:
# {1, 2, 3}

# %%
type(s1)
# Out:
# set

# %%
s2=set() #empty set
type(s2)
# Out:
# set

# %%
s1
# Out:
# {1, 2, 3}

# %%
s2={100,1,34,9,43} # set is order item . and similar data type
s2
# Out:
# {1, 9, 34, 43, 100}

# %%
s3={2,3.4,True,'nit',1+2j}
s3
# Out:
# {(1+2j), 2, 3.4, True, 'nit'}

# %%
print(s1)
print(s2)
print(s3)
# Out:
# {1, 2, 3}
# {1, 34, 100, 9, 43}
# {True, 2, 3.4, (1+2j), 'nit'}

# %% [markdown]
# ## add()

# %%
s1.add(4)
s1
# Out:
# {1, 2, 3, 4}

# %%
s1.add(4,5) 
s1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 s1.add(4,5)
#       2 s1
#
# TypeError: set.add() takes exactly one argument (2 given)

# %% [markdown]
# ## copy

# %%
s4=s1.copy() # one data type to another data type cope.
s4
# Out:
# {1, 2, 3, 4}

# %%
s4[0] # set data type indexing & slicing not allowed
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 s4[0]
#
# TypeError: 'set' object is not subscriptable

# %%
s1
# Out:
# {1, 2, 3, 4}

# %%
s3
# Out:
# {(1+2j), 2, 3.4, True, 'nit'}

# %%
s3.pop()
# Out:
# True

# %%
s3
# Out:
# {(1+2j), 2, 3.4, 'nit'}

# %%
s3.pop(2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 s3.pop(2)
#
# TypeError: set.pop() takes no arguments (1 given)

# %%
s3.removed(100)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 s3.removed(100)
#
# AttributeError: 'set' object has no attribute 'removed'

# %%
s3.discard(100)

# %%
s3
# Out:
# {(1+2j), 2, 3.4, 'nit'}

# %%
s3.discard(3.4)
s3
# Out:
# {(1+2j), 'nit'}

# %%
s2
# Out:
# {1, 9, 34, 43, 100}

# %%
s2.remove(100)
s2
# Out:
# {1, 9, 34, 43}

# %%
print(s1)
print(s2)
print(s3)
print(s4)
# Out:
# {1, 2, 3, 4}
# {1, 34, 9, 43}
# {(1+2j), 'nit'}
# {1, 2, 3, 4}

# %% [markdown]
# ## union

# %%
a={1,2,3,4,5}
b={4,5,6,7,8}
c={8,9,10}

# %%
a.union(b)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %%
a|b # union
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %% [markdown]
# ## intersection

# %%
print(a)
print(b)
print(c)
# Out:
# {1, 2, 3, 4, 5}
# {4, 5, 6, 7, 8}
# {8, 9, 10}

# %%
a.intersection(b)
# Out:
# {4, 5}

# %%
print(b&c)
# Out:
# {8}

# %% [markdown]
# ## Difference

# %%
print(a)
print(b)
print(c)
# Out:
# {1, 2, 3, 4, 5}
# {4, 5, 6, 7, 8}
# {8, 9, 10}

# %%
a.difference(b)
# Out:
# {1, 2, 3}

# %%
b-c
# Out:
# {4, 5, 6, 7}

# %%
b.difference(c)
# Out:
# {4, 5, 6, 7}

# %% [markdown]
# ## symmetric difference

# %%
print(a)
print(b)
print(c)
# Out:
# {1, 2, 3, 4, 5}
# {4, 5, 6, 7, 8}
# {8, 9, 10}

# %%
a.symmetric_difference(b)
# Out:
# {1, 2, 3, 6, 7, 8}

# %%
b^c
# Out:
# {4, 5, 6, 7, 9, 10}

# %% [markdown]
# ## symmetric_difference_update

# %%
print(a)
print(b)
print(c)
# Out:
# {1, 2, 3, 4, 5}
# {4, 5, 6, 7, 8}
# {8, 9, 10}

# %%
b.symmetric_difference_update(c)

# %%
b
# Out:
# {4, 5, 6, 7, 9, 10}

# %%
a2={1,2,3,4,5,6,7,8,9}
b2={3,4,5,6,7,8}
c2={10,20,30,40}

# %%
b2.issubset(a2)
# Out:
# True

# %%
a2.issubset(b2)
# Out:
# False

# %%
a2.issuperset(b2)
# Out:
# True

# %%
b2.issuperset(a2)
# Out:
# False

# %% [markdown]
# ## disjoint()

# %%
a={1,2,3}
b={4,5,6}

# %%
a.isdisjoint(b)
# Out:
# True

# %%
a={1,2,3}
b={3,5,6}

# %%
a.isdisjoint(b)
# Out:
# False
