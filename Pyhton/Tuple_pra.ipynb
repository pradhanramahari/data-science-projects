# %%
tup1 =()
tup1
# Out:
# ()

# %%
type(tup1)
# Out:
# tuple

# %%
tup2=(10,30,60) #tuple of integer number

# %%
tup3=(10.22,22.5,55.7)#tuple of float number

# %%
tup4=('one','two','three') #tuple of string

# %%
tup5=('hari',100,33.5,(50,100),(150,90))#nested tuple

# %%
tup6=(100,'hari',17.99) #tuple of mixed data type

# %%
tup2[0]
# Out:
# 10

# %%
tup4[0]
# Out:
# 'one'

# %%
tup4[0][0]
# Out:
# 'o'

# %%
tup4[-1]
# Out:
# 'three'

# %%
mytuple=('one','two','three','four','five','six','seven','eight')
mytuple
# Out:
# ('one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight')

# %%
mytuple[0:3]
# Out:
# ('one', 'two', 'three')

# %%
mytuple[2:5]
# Out:
# ('three', 'four', 'five')

# %%
mytuple[:3]
# Out:
# ('one', 'two', 'three')

# %%
mytuple[:2]
# Out:
# ('one', 'two')

# %%
mytuple[-3:]
# Out:
# ('six', 'seven', 'eight')

# %%
mytuple[-2:]
# Out:
# ('seven', 'eight')

# %%
mytuple[-1:]
# Out:
# ('eight',)

# %%
mytuple[:]
# Out:
# ('one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight')

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 mytuple
#
# NameError: name 'mytuple' is not defined

# %%
mytuple=('one','two','three','four','five','six','seven','eight')
mytuple
# Out:
# ('one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight')

# %%
del mytuple[0] # can't be deleted
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 del mytuple[0]
#
# TypeError: 'tuple' object doesn't support item deletion

# %%
mytuple[0]=1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 mytuple[0]=1
#
# TypeError: 'tuple' object does not support item assignment

# %%
'one' in mytuple
# Out:
# True

# %%
'six' in mytuple
# Out:
# True

# %%
mytuple
# Out:
# ('one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight')

# %%
mytuple.index('one')
# Out:
# 0

# %%
mytuple.index('eight')
# Out:
# 7

# %%
num=(90,78,98,54,3)
num
# Out:
# (90, 78, 98, 54, 3)

# %%
sorted(num)
# Out:
# [3, 54, 78, 90, 98]

# %%
sorted(num,reverse=True)
# Out:
# [98, 90, 78, 54, 3]
