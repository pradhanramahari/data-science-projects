# %%
mydic= dict() # empty dictionary
mydic
# Out:
# {}

# %%
mydic={}# empty dictionary
mydic
# Out:
# {}

# %%
mydic ={1:'one',2:'two',3:'three'}# dictionary with integer keys
mydic
# Out:
# {1: 'one', 2: 'two', 3: 'three'}

# %%
mydic =dict({1:'one',2:'two',3:'three',4:'four'}) # Create dictionary using dict()
mydic
# Out:
# {1: 'one', 2: 'two', 3: 'three', 4: 'four'}

# %%
mydic= {'A':'one','B':'two','C':'three'} # dictionary with character keys
mydic
# Out:
# {'A': 'one', 'B': 'two', 'C': 'three'}

# %%
mydic ={1:'one','A':'two',3:'three'} # dictionary with mixed keys
mydic
# Out:
# {1: 'one', 'A': 'two', 3: 'three'}

# %% [markdown]
# # Keys()

# %%
mydic.keys()
# Out:
# dict_keys([1, 'A', 3])

# %% [markdown]
# # Values()

# %%
mydic.values()
# Out:
# dict_values(['one', 'two', 'three'])

# %%
dic ={'one':1,2:'two','three':3}
dic
# Out:
# {'one': 1, 2: 'two', 'three': 3}

# %%
dic.values()
# Out:
# dict_values([1, 'two', 3])

# %% [markdown]
# # items()

# %%
mydic.items()
# Out:
# dict_items([(1, 'one'), ('A', 'two'), (3, 'three')])

# %%
dic ={'one':1,2:'two','three':3}
dic
# Out:
# {'one': 1, 2: 'two', 'three': 3}

# %%
dic.items()
# Out:
# dict_items([('one', 1), (2, 'two'), ('three', 3)])

# %%
keys = {'a' , 'b' , 'c' , 'd'}
mydict3 = dict.fromkeys(keys) # Create a dictionary from a sequence of keys
mydict3
# Out:
# {'a': None, 'c': None, 'b': None, 'd': None}

# %%
keys = {'a' , 'b' , 'c' , 'd'}
value=10
mydict3 = dict.fromkeys(keys,value) # Create a dictionary from a sequence of keys
mydict3
# Out:
# {'a': 10, 'c': 10, 'b': 10, 'd': 10}

# %%
keys={'a','b','c','d'}
value=[10,20,30,40]
mydict4= dict.fromkeys(keys,value)
mydict4
# Out:
# {'a': [10, 20, 30, 40],
#  'c': [10, 20, 30, 40],
#  'b': [10, 20, 30, 40],
#  'd': [10, 20, 30, 40]}

# %%
value.append(50)
mydict4
# Out:
# {'a': [10, 20, 30, 40, 50, 50],
#  'c': [10, 20, 30, 40, 50, 50],
#  'b': [10, 20, 30, 40, 50, 50],
#  'd': [10, 20, 30, 40, 50, 50]}

# %% [markdown]
# # Accessing Items

# %%
mydic ={1:'one',2:'two',3:'three'}
mydic
# Out:
# {1: 'one', 2: 'two', 3: 'three'}

# %%
mydic[1]# Access item using key
# Out:
# 'one'

# %%
mydic.get(1)# Access item using get() method
# Out:
# 'one'

# %%
my_job={'Name':'hari','ID':2234,'DOB':2004,'Job':'Datascinse'}
my_job
# Out:
# {'Name': 'hari', 'ID': 2234, 'DOB': 2004, 'Job': 'Datascinse'}

# %%
my_job['Name']
# Out:
# 'hari'

# %%
my_job['Job']# acess item using  KEY
# Out:
# 'Datascinse'

# %%
my_job.get('DOB')
# Out:
# 2004

# %% [markdown]
# # Add, Remove & Change Items

# %%
mydic5 ={'Name':'sunil','ID':977,'DOB':2004,'Address':'odisha'}
mydic5
# Out:
# {'Name': 'sunil', 'ID': 977, 'DOB': 2004, 'Address': 'odisha'}

# %%
mydic5['DOB']=2003               # Changing Dictionary Items
mydic5['Address']='cuttack'
mydic5
# Out:
# {'Name': 'sunil', 'ID': 977, 'DOB': 2003, 'Address': 'cuttack'}

# %%
mydic5.update({'Address':'ganjam'})
mydic5
# Out:
# {'Name': 'sunil', 'ID': 977, 'DOB': 2003, 'Address': 'ganjam'}

# %%
mydic5.update({'Name':'hari'})#update items in the dictionary
mydic5.update({'job':'AI'})
mydic5
# Out:
# {'Name': 'hari', 'ID': 977, 'DOB': 2003, 'Address': 'ganjam', 'job': 'AI'}

# %% [markdown]
# # remove

# %%
student={'name' : 'hari',
        'age':22
        }
student
# Out:
# {'name': 'hari', 'age': 22}

# %%
student.pop('age')
# Out:
# 22

# %%
student
# Out:
# {'name': 'hari'}

# %%
student1={'name' : 'sunil',
        'age':23
        }
student1
# Out:
# {'name': 'sunil', 'age': 23}

# %%
student1.popitem()# A random item is removed
# Out:
# ('age', 23)

# %%
student1
# Out:
# {'name': 'sunil'}

# %%
mydict ={'name':'hari','age':23}
mydict
# Out:
# {'name': 'hari', 'age': 23}

# %%
del[mydict['age']]# Removing item using del method
mydict
# Out:
# {'name': 'hari'}

# %%
mydict.clear# Delete all items of the dictionary using clear method
# Out:
# <function dict.clear()>

# %%
del mydict# Delete the dictionary object
mydict
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 del mydict
#       2 mydict
#
# NameError: name 'mydict' is not defined

# %% [markdown]
# # Copy Dictionary

# %%
mydict = {'Name':'Asif' , 'ID': 12345 , 'DOB': 1991 , 'Address' : 'Hilsinki'}
mydict
# Out:
# {'Name': 'Asif', 'ID': 12345, 'DOB': 1991, 'Address': 'Hilsinki'}

# %%
mydict2=mydict  # Create a new reference "mydict2"

# %%
id(mydict),id(mydict2)# The address of both mydict & mydict1 will be the same
# Out:
# (2675161149504, 2675161149504)

# %%
mydict3=mydict.copy()# Create a copy of the dictionary

# %%
id(mydict3)#The address of mydict3 will be different from mydict because mydic
# Out:
# 2675161138304
