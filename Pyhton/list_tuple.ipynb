# %%
list1 = [] #empty list

# %%
print(type(list1))
# Out:
# <class 'list'>

# %%
list2=[10,30,20] #list of integers numbers

# %%
list3=[10.33,44.88,90.8] # list of float numbers

# %%
list4=['one','two','three'] # list of string

# %%
list5=['welcome',90,[20,30,40],[150,190]] # mixed data type

# %%
list7 = ['Asif', 25 ,[50, 100],[150, 90] , {'John' , 'David'}]

# %%
len(list4) #lenght of list
# Out:
# 3

# %%
list2[0] # Retreive first element of the list
# Out:
# 10

# %%
list4[0] # Retreive first element of the list
# Out:
# 'one'

# %%
list4[0][1]
# Out:
# 'n'

# %%
list4[-1]
# Out:
# 'three'

# %%
list5[-1]
# Out:
# [150, 190]

# %%
mylist = ['one' , 'two' , 'three' , 'four' , 'five' , 'six' , 'seven' , 'eight']

# %%
mylist
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
mylist[0:3]
# Out:
# ['one', 'two', 'three']

# %%
mylist[:3]
# Out:
# ['one', 'two', 'three']

# %%
mylist[:2]
# Out:
# ['one', 'two']

# %%
mylist[-3]
# Out:
# 'six'

# %%
mylist[-1]
# Out:
# 'eight'

# %%
mylist[::]
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
mylist
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
mylist.append('nine')
mylist
# Out:
# ['one',
#  'two',
#  'three',
#  'four',
#  'five',
#  'six',
#  'seven',
#  'eight',
#  'nine',
#  'nine']

# %%
mylist.insert(9,'ten')
mylist
# Out:
# ['one',
#  'two',
#  'three',
#  'four',
#  'five',
#  'six',
#  'seven',
#  'eight',
#  'nine',
#  'ten',
#  'nine']

# %%
mylist.insert(1,'ONE')
mylist
# Out:
# ['one',
#  'ONE',
#  'two',
#  'three',
#  'four',
#  'five',
#  'six',
#  'seven',
#  'eight',
#  'nine',
#  'ten',
#  'nine']

# %%
mylist.remove("ONE")
mylist
# Out:
# ['one',
#  'two',
#  'three',
#  'four',
#  'five',
#  'six',
#  'seven',
#  'eight',
#  'nine',
#  'ten',
#  'nine']

# %%
mylist.pop()
# Out:
# 'nine'

# %%
mylist
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine', 'ten']

# %%
mylist.pop(9)
# Out:
# 'ten'

# %%
mylist
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine']

# %%
mylist[0]=1
mylist[1]=2
mylist[2]=3
mylist
# Out:
# [1, 2, 3, 'four', 'five', 'six', 'seven', 'eight', 'nine']

# %%
mylist.clear()

# %%
mylist
# Out:
# []

# %%
del mylist

# %%
mylist
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 mylist
#
# NameError: name 'mylist' is not defined

# %%
mylist = ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine']
mylist
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine']

# %%
mylist1 = mylist
mylist1
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine']

# %%
id(mylist) , id(mylist1) # difference address
# Out:
# (2439369539200, 2439369539200)

# %%
type(mylist1)
# Out:
# list

# %%
mylist1
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine']

# %%
mylist1[0]=1
mylist1
# Out:
# [1, 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine']

# %%
mylist
# Out:
# [1, 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine']

# %%
list1 = ['one', 'two', 'three', 'four']
list2 = ['five', 'six', 'seven', 'eight']

# %%
list3=list1 + list2
list3
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
list1.extend(list2)
list1
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
list2
# Out:
# ['five', 'six', 'seven', 'eight']

# %%
list1
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
'two' in list1
# Out:
# True

# %%
'ten' in list1
# Out:
# False

# %%
list1
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
list1.reverse()
list1
# Out:
# ['eight', 'seven', 'six', 'five', 'four', 'three', 'two', 'one']

# %%
list1[::-1]
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
mylist3 = [9,5,2,99,12,88,34]
mylist3.sort() # Sort list in ascending order
mylist3
# Out:
# [2, 5, 9, 12, 34, 88, 99]

# %%
mylist3
# Out:
# [2, 5, 9, 12, 34, 88, 99]

# %%
mylist3.sort(reverse=True)# Sort list in descending order
mylist3
# Out:
# [99, 88, 34, 12, 9, 5, 2]

# %%
list10 =['one', 'two', 'three', 'four', 'one', 'one', 'two', 'three']
list10
# Out:
# ['one', 'two', 'three', 'four', 'one', 'one', 'two', 'three']

# %%
list10.count('one')
# Out:
# 3

# %%
list10.count('two')
# Out:
# 2

# %%
list10.count("three")
# Out:
# 2

# %%
L1 = [1,2,3,4,0]
L1
# Out:
# [1, 2, 3, 4, 0]

# %%
all(L1)
# Out:
# False

# %%
L2= [1,2,3,4]
L2
# Out:
# [1, 2, 3, 4]

# %%
all(L2)
# Out:
# True

# %%
any(L1)
# Out:
# True

# %%
all(L1)
# Out:
# False
