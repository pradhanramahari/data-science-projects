# %%
"welcome to odisha"
# Out:
# 'welcome to odisha'

# %%
"my name is hari"
# Out:
# 'my name is hari'

# %%
print("hello python")
# Out:
# hello python

# %%
print('my name is hari')
# Out:
# my name is hari
