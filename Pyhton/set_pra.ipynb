# %% [markdown]
# ## set

# %%
s={}
s

# %%
type(s)

# %%
s1={1,2,3,3} # it is set 
s1

# %%
type(s1)

# %%
s2=set() #empty set
s2

# %%
type(s2)

# %%
s3={100,1,34,9,43} # set is order item if user difine similer data dype 
s3

# %%
s4={2,34.5,1+2j,True,'NIT'} 
s4

# %%
print(s1)
print(s2)
print(s3)
print(s4)

# %%
s3

# %%
s3.add(90)# only one argument pass add function
s3

# %%
s3[0]# set not allowed index & slicing

# %%
s3

# %%
s2

# %%
s4

# %%
s4.pop()# rendom elements remove

# %%
s4.pop()

# %%
s5={10,20,40}
s5

# %%
s5.discard(20)
s5

# %%
s5.discard(100) # not error
s5

# %% [markdown]
# # union()

# %%
a={1,2,3,4,5}
b={4,5,6,7,8}
c={8,9,10}

# %%
a.union(b,c)

# %%
a|b|c

# %% [markdown]
# # intersection

# %%
print(a)
print(b)
print(c)

# %%
a.intersection(b) # only common value

# %%
b&c
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 b&c
#
# NameError: name 'b' is not defined

# %% [markdown]
# # difference

# %%
print(a)
print(b)
print(c)

# %%
a-b # not common item

# %%
b.difference(c)

# %% [markdown]
# # symmetric_difference()

# %%
print(a)
print(b)
print(c)

# %%
a.symmetric_difference(b) # common iteam deleted.

# %%
b^c

# %%
s1={1,2,3,4}
s1

# %%
s5=frozenset(s1)

# %%
s5

# %%
type(s5)

# %%
s5.add(9)

# %% [markdown]
# # symmetric_difference_update

# %%
a={1,2,3,4,5}
b={4,5,6,7,8}
c={8,9,10}

# %%
print(a)
print(b)
print(c)
# Out:
# {1, 2, 3, 4, 5}
# {4, 5, 6, 7, 8}
# {8, 9, 10}

# %%
a.symmetric_difference_update(b)

# %%
a
# Out:
# {1, 2, 3, 6, 7, 8}

# %%
b.symmetric_difference_update(c)

# %%
b
# Out:
# {4, 5, 6, 7, 9, 10}

# %%
a2={1,2,3,4,5,6,7,8,9}
b2={3,4,5,6,7,8}
c2={10,20,30,40}

# %%
a2.issuperset(b)
# Out:
# False
