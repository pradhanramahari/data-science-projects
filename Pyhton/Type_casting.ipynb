# %% [markdown]
# ## Type Casting

# %%
110.34
# Out:
# 110.34

# %% [markdown]
# # int to float

# %%
int(110.45)
# Out:
# 110

# %%
int(True)
# Out:
# 1

# %%
int(1+2j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 int(1+2j)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %%
int('10')
# Out:
# 10

# %%
int('hari')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 int('hari')
#
# ValueError: invalid literal for int() with base 10: 'hari'

# %%
int('kara')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 int('kara')
#
# ValueError: invalid literal for int() with base 10: 'kara'

# %%
# in type casting while type caste while typecast from all other datatype to int possible exept complex & text string

# %% [markdown]
# # other datatype to float

# %%
float(19)
# Out:
# 19.0

# %%
float(True)
# Out:
# 1.0

# %%
float(False)
# Out:
# 0.0

# %%
float(1+2j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 float(1+2j)
#
# TypeError: float() argument must be a string or a real number, not 'complex'

# %%
float('10') #number string
# Out:
# 10.0

# %%
float('text')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 float('text')
#
# ValueError: could not convert string to float: 'text'

# %% [markdown]
# # other datatype  to boolean

# %%
bool(2)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool(2.3)
# Out:
# True

# %%
bool(0.90)
# Out:
# True

# %%
bool(1+2j)
# Out:
# True

# %%
bool('10')
# Out:
# True

# %%
bool( )
# Out:
# False

# %%
bool('tx')
# Out:
# True

# %% [markdown]
# # all other datatype to complex

# %%
complex(2)
# Out:
# (2+0j)

# %%
complex(3,8)
# Out:
# (3+8j)

# %%
complex(9,8,7)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 complex(9,8,7)
#
# TypeError: complex() takes at most 2 arguments (3 given)

# %%
complex(3,4)
# Out:
# (3+4j)

# %%
complex(2.5+8.9)
# Out:
# (11.4+0j)

# %%
complex(True)
# Out:
# (1+0j)

# %%
complex(False)
# Out:
# 0j

# %%
complex('10')
# Out:
# (10+0j)

# %%
complex('hari')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 complex('hari')
#
# ValueError: complex() arg is a malformed string

# %%
complex('10','20')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 complex('10','20')
#
# TypeError: complex() can't take second arg if first is a string

# %% [markdown]
# # all other data type to String

# %%
str(10)
# Out:
# '10'

# %%
str(10.8)
# Out:
# '10.8'

# %%
str(True)
# Out:
# 'True'

# %%
str(False)
# Out:
# 'False'

# %%
str(10+2j)
# Out:
# '(10+2j)'
