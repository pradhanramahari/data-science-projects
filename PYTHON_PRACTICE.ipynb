# %% [markdown]
# ## List

# %%
list1=[]
print(type(list1))
# Out:
# <class 'list'>

# %%
list2=[10,20,30] #integers number
list2
# Out:
# [10, 20, 30]

# %%
list3=[10.5,20.5,30.5] #float number
list3
# Out:
# [10.5, 20.5, 30.5]

# %%
list4=['one','two',"three"]# list of string
list4
# Out:
# ['one', 'two', 'three']

# %%
list5=['hari',24,[50,100],[300,400]] #nested list
list5
# Out:
# ['hari', 24, [50, 100], [300, 400]]

# %% [markdown]
# ## list indexing

# %%
list2[0]
# Out:
# 10

# %%
list4[0]
# Out:
# 'one'

# %%
list4[0][2]
# Out:
# 'e'

# %%
list4[2][3]
# Out:
# 'e'

# %%
list4[-1]
# Out:
# 'three'

# %%
list5[-1]
# Out:
# [300, 400]

# %%
list5[-2]
# Out:
# [50, 100]

# %% [markdown]
# ## List Slicing

# %%
mylist = ['one' , 'two' , 'three' , 'four' , 'five' , 'six' , 'seven' , 'eight']

# %%
mylist[3:6]
# Out:
# ['four', 'five', 'six']

# %%
mylist[1:5]
# Out:
# ['two', 'three', 'four', 'five']

# %%
mylist[:3]
# Out:
# ['one', 'two', 'three']

# %%
mylist[:2]
# Out:
# ['one', 'two']

# %%
mylist[-3:]
# Out:
# ['six', 'seven', 'eight']

# %%
mylist[-2:]
# Out:
# ['seven', 'eight']

# %%
mylist[-1:]
# Out:
# ['eight']

# %%
mylist[:] #all print
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %% [markdown]
# ## add,remove,change

# %%
mylist
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
mylist.append('nine') #append == add
mylist
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine']

# %%
mylist.insert(9,'ten')
mylist
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine', 'ten']

# %%
mylist.insert(1,"ONE")
mylist
# Out:
# ['one',
#  'ONE',
#  'two',
#  'three',
#  'four',
#  'five',
#  'six',
#  'seven',
#  'eight',
#  'nine',
#  'ten']

# %%
mylist.remove('ONE')
mylist
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine', 'ten']

# %%
mylist.pop()
mylist
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine']

# %%
mylist.pop(2)
mylist
# Out:
# ['one', 'two', 'five', 'six', 'seven', 'eight', 'nine']

# %%
del mylist[4]
mylist
# Out:
# ['one', 'two', 'five', 'six', 'eight', 'nine']

# %%
mylist[0]=1
mylist[1]=2
mylist[2]=3
mylist
# Out:
# [1, 2, 3, 'six', 'eight', 'nine']

# %%
mylist.clear()
mylist
# Out:
# []

# %% [markdown]
# ## copy list

# %%
mylist = ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine']
mylist
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine']

# %%
mylist1=mylist

# %%
mylist1
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine']

# %%
id(mylist1),id(mylist) ## address both are same
# Out:
# (2208334779008, 2208334779008)

# %%
mylist2=mylist.copy()
mylist2
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine']

# %%
type(mylist1),type(mylist)
# Out:
# (list, list)

# %%
print(mylist)
print(mylist1)
print(mylist2)
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine']
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine']
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine']

# %%
list1 = ['one', 'two', 'three', 'four']
list2 = ['five', 'six', 'seven', 'eight']

# %%
sum3=list1 + list2
sum3
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
list1.extend(list2)
list1
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
list2
# Out:
# ['five', 'six', 'seven', 'eight']

# %%
list1
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
'three' in list1
# Out:
# True

# %%
'ten' in list1
# Out:
# False

# %% [markdown]
# ## reverse & sort list

# %%
list1
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
list1.reverse()
list1
# Out:
# ['eight', 'seven', 'six', 'five', 'four', 'three', 'two', 'one']

# %%
list1=list1[::-1]
list1
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %% [markdown]
# ## sort()

# %%
mylist3 = [9,5,2,99,12,88,34]
mylist3
# Out:
# [9, 5, 2, 99, 12, 88, 34]

# %%
mylist3.sort() ## Sort list in ascending order

mylist3
# Out:
# [2, 5, 9, 12, 34, 88, 99]

# %%
mylist3.sort( reverse=True) # Sort list in descending order
mylist3
# Out:
# [99, 88, 34, 12, 9, 5, 2]

# %% [markdown]
# ## count

# %%
list10 =['one', 'two', 'three', 'four', 'one', 'one', 'two', 'three']
list10
# Out:
# ['one', 'two', 'three', 'four', 'one', 'one', 'two', 'three']

# %%
list10.count("one")
# Out:
# 3

# %%
list10.count("two")
# Out:
# 2

# %%
list10.count("four")
# Out:
# 1
